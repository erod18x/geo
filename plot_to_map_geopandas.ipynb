# %%
import pandas as pd

data = pd.read_csv('1EA793E93C7BD241EED1ED26F31E0288DE5E3A75.csv', low_memory=False)

print('Total Rows: {0}'.format(len(data)))
# Out:
# Total Rows: 50903

# %%
print(list(data))
# Out:
# ['Unnamed: 0', 'id', 'ingested_at', 'ip_address.as_organization', 'ip_address.asn', 'ip_address.city', 'ip_address.continent', 'ip_address.country', 'ip_address.country_code', 'ip_address.domain', 'ip_address.ip_address', 'ip_address.isp', 'ip_address.latitude', 'ip_address.longitude', 'ip_address.organization', 'ip_address.port', 'ip_address.region', 'platform_url', 'torrent', 'torrent_id', 'tracker']

# %%
data.head()
# Out:
#    Unnamed: 0                      id                  ingested_at  \
# 0           0  zepEXdS4TA-HKb_OjUpoog  2018-12-01T23:21:59.168042Z
# 1           1  VWw0P071SOyCLadqVQGOyA  2018-12-01T23:21:59.037508Z
# 2           2  yR0oE1I-RVaAdVhBhNQgKg  2018-12-01T23:21:57.985104Z
# 3           3  f4fr1Q6mQd6XgI38rDd7IQ  2018-12-01T23:21:56.528831Z
# 4           4  Mh256cddRueLcrO0eIZwAA  2018-12-01T23:21:55.709038Z
#
#               ip_address.as_organization  ip_address.asn ip_address.city  \
# 0  Traffic Broadband Communications Ltd.         48452.0           Sofia
# 1                               MTS PJSC         29497.0       Krasnodar
# 2                    Uninet S.A. de C.V.          8151.0         Zapopan
# 3                  No.31,Jin-rong Street          4134.0         Chengdu
# 4                               MTS PJSC         29497.0       Krasnodar
#
#   ip_address.continent ip_address.country ip_address.country_code  \
# ...

# %%
country = data['ip_address.country']
city = data['ip_address.city']
lat = data['ip_address.latitude']
lng = data['ip_address.longitude']

# %%
data['coords'] = data[['ip_address.longitude','ip_address.latitude']].values.tolist()

# %%
data.iloc[:20,3:]
# Out:
#                ip_address.as_organization  ip_address.asn ip_address.city  \
# 0   Traffic Broadband Communications Ltd.         48452.0           Sofia
# 1                                MTS PJSC         29497.0       Krasnodar
# 2                     Uninet S.A. de C.V.          8151.0         Zapopan
# 3                   No.31,Jin-rong Street          4134.0         Chengdu
# 4                                MTS PJSC         29497.0       Krasnodar
# 5                Reflected Networks, Inc.         29789.0         Waltham
# 6                                   TE-AS          8452.0           Cairo
# 7                               Elisa Oyj           790.0           Turku
# 8             NTT PC Communications, Inc.          2514.0           Osaka
# 9                Reflected Networks, Inc.         29789.0         Waltham
# 10  Traffic Broadband Communications Ltd.         48452.0           Sofia
# 11      Asia Pacific On-line Service Inc.          7482.0     Tainan City
# ...
